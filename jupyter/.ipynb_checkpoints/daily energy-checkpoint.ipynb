# %%
# import sys
# !{sys.executable} -m pip install robobrowser
import requests
from requests.auth import HTTPBasicAuth
import json
import datetime
from dateutil import parser

# %%
req = requests.get('http://expertpowerplus.com:8080/api/Login?userName=ppl&pass=Wyre1234')

# %%
auth_key_name = (list(req.cookies)[0]).name #get name of cookie unit used to be (.ASPXAUTH) chnaged to (form_p)
auth_key_value = dict(req.cookies).get(auth_key_name) #get actual cookie unit

# %%
cookie = {auth_key_name: auth_key_value}
device = "128166"#"125639" #133813
url_lastreading = f'http://expertpowerplus.com:8080/api/basic/{device}/LastReading'

url_period_reading = f'http://expertpowerplus.com:8080/api/Basic?startDate=2019-08-11&endDate=c&deviceId={device}'
url_data_logs = f'http://www.expertpowerplus.com:8080/api/basic/{device}/Datalogs?startDate=2019-07-17&endDate=2019-08-01&datalogNum=1'

r = requests.get(url_data_logs, cookies=cookie)

# %%
data = r.json()
(data)
# Out:
# {'resultCode': 200,
#  'message': None,
#  'data': [{'deviceID': 128166,
#    'recordTime': '2019-07-31T23:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050757.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 44.122, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T23:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050747.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 39.777, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T23:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050736.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 48.272, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T23:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050725.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 40.676, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T22:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050710.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 71.863, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T22:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050688.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 93.85300000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T22:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050660.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 121.077, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T22:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050632.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 107.126, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T21:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050604.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 122.59100000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T21:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050577.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 106.85600000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T21:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050550.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 109.08500000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T21:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050523.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 96.557, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T20:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050496.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 115.083, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T20:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050469.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 118.715, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T20:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050440.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 126.687, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T20:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050412.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 111.541, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T19:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050383.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 134.177, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T19:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050354.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 119.151, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T19:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050322.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3249.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 160.943, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3249.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T19:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050300.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 120.639, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T18:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050270.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 110.72800000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T18:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050240.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 135.983, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T18:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050210.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 128.923, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T18:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050179.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 127.816, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T17:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050148.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 127.444, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T17:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050116.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 125.974, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T17:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050084.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 128.147, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T17:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050052.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 126.8, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T16:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1050019.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 144.393, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T16:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049983.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 151.074, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T16:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049946.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 149.047, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T16:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049909.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 146.343, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T15:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049870.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 156.747, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T15:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049831.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 170.109, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T15:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049792.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 174.555, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T15:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049752.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 159.211, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T14:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049713.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 143.42600000000002, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T14:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049674.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 149.45600000000002, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T14:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049635.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 166.85, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T14:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049596.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 151.993, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T13:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049558.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 147.413, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T13:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049520.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 141.709, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T13:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049483.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 130.77700000000002, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T13:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049446.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 142.76500000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T12:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049408.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 150.844, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T12:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049371.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 143.64000000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T12:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049335.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 156.151, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T12:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049298.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 148.076, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T11:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049261.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 147.976, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T11:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049223.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 139.465, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T11:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049184.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 146.552, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T11:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049146.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 151.656, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T10:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049108.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 163.505, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T10:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049068.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 153.53300000000002, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T10:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1049029.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 147.667, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T10:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048989.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 149.44400000000002, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T09:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048952.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 154.62800000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T09:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048913.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 144.304, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T09:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048876.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3247.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 159.061, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3247.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T09:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048843.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 142.441, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T08:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048805.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 156.724, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T08:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048768.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 153.815, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T08:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048731.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 146.124, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T08:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048694.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 154.422, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T07:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048655.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 142.368, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T07:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048618.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 161.767, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T07:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048580.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 152.409, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T07:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048544.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 129.597, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T06:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048509.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 150.57, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T06:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048481.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 123.497, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T06:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048451.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 112.553, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T06:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048427.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 53.792, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T05:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048415.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 44.639, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T05:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048403.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 45.224000000000004, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T05:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048391.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 40.038000000000004, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T05:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048380.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 43.029, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T04:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048369.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 36.01, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T04:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048358.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 46.964, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T04:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048347.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 45.002, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T04:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048336.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 40.694, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T03:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048326.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 39.477000000000004, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T03:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048315.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 47.276, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T03:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048304.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 39.944, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T03:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048294.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 40.982, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T02:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048284.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 39.44, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T02:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048274.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 39.412, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T02:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048264.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 38.574, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T02:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048254.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 43.148, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T01:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048245.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 39.796, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T01:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048235.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 42.087, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T01:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048226.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 36.688, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T01:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048216.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 37.068, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T00:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048206.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 34.980000000000004, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T00:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048196.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 35.895, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T00:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048186.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 35.956, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-31T00:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048176.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 38.373, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-30T23:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048165.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 47.708, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-30T23:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048154.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3245.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 44.159, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3245.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-30T23:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1048143.0,
#      'units': ''},
# ...
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026796.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 55.518, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T21:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026782.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 62.532000000000004, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T21:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026767.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 64.57600000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T21:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026748.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 79.549, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T20:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026730.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 65.065, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T20:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026711.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 86.177, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T20:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026692.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 77.612, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T20:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026674.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 68.131, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T19:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026655.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 79.72, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T19:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026637.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 68.834, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T19:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026619.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 68.425, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T19:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026601.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 74.943, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T18:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026582.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 75.431, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T18:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026564.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 66.88, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T18:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026546.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 72.422, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T18:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026527.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 82.072, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T17:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026509.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 69.46600000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T17:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026489.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 81.431, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T17:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026468.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 80.765, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T17:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026446.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 82.765, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T16:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026424.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 79.354, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T16:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026402.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 88.43900000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T16:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026381.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 80.245, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T16:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026361.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 75.642, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T15:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026340.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 98.622, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T15:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026319.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 89.96600000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T15:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026296.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 87.915, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T15:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026275.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 88.352, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T14:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026254.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 73.799, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T14:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026233.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 80.738, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T14:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026215.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 73.794, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T14:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026197.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 72.35000000000001, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-07-21T13:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 1026179.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 3163.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 66.412, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 3163.0, 'units': '&nbsp;'}]},
#   ...]}

# %%
readings = data['data'][0]['data']
utility_times = []
gen_times = []

for readings in reversed(data['data']):
    record_time = readings["recordTime"]
    digital_in = readings["data"][0]["value"]
    energy_1 = readings["data"][1]["value"]
    energy_2 = readings["data"][2]["value"]
    total_energy = readings["data"][3]["value"]
    
    if digital_in == 0:
        utility_times.append((record_time, energy_1))
        
    elif digital_in == 1:
        gen_times.append((record_time, energy_1))

# %%
def get_time_dif(a, b):
    
    c = b - a
    hours = c.seconds/3600
    return hours

# %%
def format_date(date):###THIS FUNCTION CONVERTS DATE FROM DD-MM-YYY TO YYY-MM-DD

    datetime_object = parser.parse(date)

    return datetime_object

# %%
nums = data["data"].copy()
nums.reverse()
utility_hrs = []
utility_kwh = []
gen1_hrs = []
gen1_kwh = []
gen2_hrs = []
gen2_kwh = []

while len(nums) > 1:
    x,y = nums.pop(0), nums[0]
    
    x_di = x["data"][0]["value"]
    y_di = y["data"][0]["value"]
    x_time, y_time = format_date(x["recordTime"]), format_date(y["recordTime"])
    x_kwh, y_kwh = x["data"][1]["value"], y["data"][1]["value"]
    
    if x_di == 0 and y_di == 1 or y_di == 2:
        time_diff = get_time_dif(x_time, y_time)
        kwh_diff = y_kwh - x_kwh
        if y_di == 1:
            gen1_hrs.append(time_diff)
            gen1_kwh.append(kwh_diff)
        
        elif y_di == 2:
            gen2_hrs.append(time_diff)
            gen2_kwh.append(kwh_diff)

        
    elif x_di == 1 and y_di == 0:
        time_diff = get_time_dif(x_time, y_time)
        kwh_diff = y_kwh -x_kwh
        utility_hrs.append(time_diff)
        utility_kwh.append(kwh_diff)
        
        
    elif x_di == y_di == 1 or x_di == y_di == 2:
        time_diff = get_time_dif(x_time, y_time)
        kwh_diff = y_kwh -x_kwh
        if y_di == 1:
            gen1_hrs.append(time_diff)
            gen1_kwh.append(kwh_diff)
        
        elif y_di == 2:
            gen2_hrs.append(time_diff)
            gen2_kwh.append(kwh_diff)

    elif x_di == y_di == 0:
        time_diff = get_time_dif(x_time, y_time)
        kwh_diff = y_kwh - x_kwh
        utility_hrs.append(time_diff)
        utility_kwh.append(kwh_diff)
    
print(sum(utility_hrs), sum(gen1_hrs), sum(gen2_hrs))
print(sum(utility_kwh), sum(gen1_kwh), sum(gen2_kwh))
# print("\n")
# Out:
# 277.0 82.75 0
# 23480.0 10944.0 0
