# %%
# import sys
# !{sys.executable} -m pip install robobrowser
import requests
from requests.auth import HTTPBasicAuth
import json

# %%
req = requests.get('http://expertpowerplus.com/API/api/Login?userName=ppl&pass=Wyre1234')

# %%
auth_key_name = (list(req.cookies)[0]).name #get name of cookie unit used to be (.ASPXAUTH) chnaged to (form_p)
auth_key_value = dict(req.cookies).get(auth_key_name) #get actual cookie unit

# %%
cookie = {auth_key_name: auth_key_value}
device = "128166" #133813
url_lastreading = f'http://expertpowerplus.com/API/api/basic/{device}/LastReading'
url_period_reading = f'http://expertpowerplus.com/API/api/Basic?startDate=2019-06-29&endDate=c&deviceId={device}'
url_data_logs = f'http://www.expertpowerplus.com:8080/api/basic/{device}/Datalogs?startDate=2019-04-15&endDate=2019-04-16&datalogNum=1'

r = requests.get(url_data_logs, cookies=cookie)

# # print(r.content)
# Out:
# b'{"resultCode":200,"message":null,"data":[{"deviceID":128166,"recordTime":"2019-04-15T23:30:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801285.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":45.269,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T23:15:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801273.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":44.829,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T23:00:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801261.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":57.143,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T22:45:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801248.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":50.313,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T22:30:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801233.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":80.491,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T22:15:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801207.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":105.132,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T22:00:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801177.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":117.195,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T21:45:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801145.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":121.222,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T21:30:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801114.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":120.415,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID":128166,"recordTime":"2019-04-15T21:15:00","data":[{"description":"Digital Input #1","value":0.0,"units":"&nbsp;"},{"description":"Summary Energy Register #1","value":801083.0,"units":""},{"description":"Summary Energy Register #2","value":2356.0,"units":""},{"description":"Total kW","value":127.437,"units":"kW"},{"description":"Pulse counter #1","value":2356.0,"units":"&nbsp;"}]},{"deviceID": ...

# %%
x = (r.content)
data = json.loads(x)
data
# Out:
# {'resultCode': 200,
#  'message': None,
#  'data': [{'deviceID': 128166,
#    'recordTime': '2019-04-15T23:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801285.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 45.269, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T23:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801273.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 44.829, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T23:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801261.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 57.143, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T22:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801248.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 50.313, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T22:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801233.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 80.491, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T22:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801207.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 105.132, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T22:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801177.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 117.195, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T21:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801145.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 121.222, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T21:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801114.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 120.415, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T21:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801083.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 127.437, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T21:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801052.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 123.553, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T20:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 801022.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 127.353, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T20:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800991.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 140.305, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T20:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800960.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2356.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 128.446, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2356.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T20:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800933.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 137.071, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T19:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800901.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 121.639, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T19:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800869.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 129.842, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T19:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800837.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 119.694, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T19:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800804.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 132.393, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T18:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800772.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 59.357, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T18:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800745.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 131.704, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T18:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800712.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 129.97, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T18:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800677.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 142.93, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T17:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800641.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2353.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 139.288, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2353.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T17:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800609.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 159.207, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T17:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800569.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 170.13, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T17:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800528.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 167.369, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T16:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800485.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 192.128, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T16:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800441.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 180.931, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T16:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800394.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 195.745, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T16:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800349.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 168.911, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T15:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800304.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 166.104, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T15:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800261.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 170.161, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T15:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800218.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 175.873, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T15:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800175.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 161.443, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T14:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800132.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 195.352, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T14:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800087.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 173.105, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T14:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 800043.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 180.614, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T14:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799999.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 176.008, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T13:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799957.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 169.24, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T13:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799914.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 176.072, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T13:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799871.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 174.147, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T13:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799828.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 162.951, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T12:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799785.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 180.112, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T12:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799742.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 169.018, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T12:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799697.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 174.032, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T12:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799653.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 189.869, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T11:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799608.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 183.164, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T11:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799562.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 179.574, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T11:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799516.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 200.401, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T11:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799471.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 179.28, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T10:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799423.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 188.604, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T10:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799376.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 196.796, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T10:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799328.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 175.862, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T10:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799281.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 192.647, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T09:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799233.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 196.949, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T09:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799183.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 206.689, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T09:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799133.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 201.007, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T09:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799084.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 211.813, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T08:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 799035.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 199.957, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T08:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798986.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 194.15, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T08:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798938.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 194.217, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T08:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798891.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 181.635, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T07:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798844.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 169.484, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T07:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798804.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 145.638, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T07:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798764.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 158.218, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T07:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798727.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 156.696, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T06:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798690.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2350.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 68.335, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2350.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T06:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798657.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 124.011, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T06:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798624.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 145.884, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T06:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798599.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 67.051, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T05:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798584.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 56.445, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T05:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798571.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 47.231, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T05:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798559.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 37.839, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T05:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798548.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 47.492, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T04:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798536.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 42.657, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T04:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798525.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 48.401, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T04:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798514.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 45.28, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T04:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798503.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 36.306, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T03:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 0.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798492.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2349.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 67.893, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2349.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T03:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798483.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 51.316, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T03:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798471.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 46.276, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T03:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798460.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 45.326, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T02:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798449.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 51.712, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T02:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798437.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 49.679, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T02:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798424.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 59.223, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T02:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798412.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 31.375, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T01:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798401.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 39.321, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T01:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798389.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 50.776, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T01:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798377.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 53.768, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T01:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798364.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 42.678, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T00:45:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798352.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 62.724, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T00:30:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798341.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 44.057, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T00:15:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798329.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 42.748, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]},
#   {'deviceID': 128166,
#    'recordTime': '2019-04-15T00:00:00',
#    'data': [{'description': 'Digital Input #1',
#      'value': 1.0,
#      'units': '&nbsp;'},
#     {'description': 'Summary Energy Register #1',
#      'value': 798316.0,
#      'units': ''},
#     {'description': 'Summary Energy Register #2',
#      'value': 2346.0,
#      'units': ''},
#     {'description': 'Total kW', 'value': 45.385, 'units': 'kW'},
#     {'description': 'Pulse counter #1', 'value': 2346.0, 'units': '&nbsp;'}]}]}

# %%
readings = (data['data'][0]['data'])
# # # print(data['data'][0]["recordTime"])
for readings in reversed(data['data']):
    
    # # print(readings["recordTime"], readings["data"][0]["value"],  readings["data"][1]["value"],  readings["data"][2]["value"],  readings["data"][3]["value"],  "\n\n\n\n")
# Out:
# 2019-04-15T00:00:00 1.0 798316.0 2346.0 45.385
#
#
#
#
# 2019-04-15T00:15:00 1.0 798329.0 2346.0 42.748
#
#
#
#
# 2019-04-15T00:30:00 1.0 798341.0 2346.0 44.057
#
#
#
#
# 2019-04-15T00:45:00 1.0 798352.0 2346.0 62.724
#
#
#
#
# 2019-04-15T01:00:00 1.0 798364.0 2346.0 42.678
#
#
#
#
# 2019-04-15T01:15:00 1.0 798377.0 2346.0 53.768
#
#
#
#
# 2019-04-15T01:30:00 1.0 798389.0 2346.0 50.776
#
#
#
#
# 2019-04-15T01:45:00 1.0 798401.0 2346.0 39.321
#
#
#
#
# 2019-04-15T02:00:00 1.0 798412.0 2346.0 31.375
#
#
#
#
# 2019-04-15T02:15:00 1.0 798424.0 2346.0 59.223
#
#
#
#
# 2019-04-15T02:30:00 1.0 798437.0 2346.0 49.679
#
#
#
#
# 2019-04-15T02:45:00 1.0 798449.0 2346.0 51.712
#
#
#
#
# 2019-04-15T03:00:00 1.0 798460.0 2346.0 45.326
#
#
#
#
# 2019-04-15T03:15:00 1.0 798471.0 2346.0 46.276
#
#
#
#
# 2019-04-15T03:30:00 1.0 798483.0 2346.0 51.316
#
#
#
#
# 2019-04-15T03:45:00 0.0 798492.0 2349.0 67.893
#
#
#
#
# 2019-04-15T04:00:00 0.0 798503.0 2349.0 36.306
#
#
#
#
# 2019-04-15T04:15:00 0.0 798514.0 2349.0 45.28
#
#
#
#
# 2019-04-15T04:30:00 0.0 798525.0 2349.0 48.401
#
#
#
#
# 2019-04-15T04:45:00 0.0 798536.0 2349.0 42.657
#
#
#
#
# 2019-04-15T05:00:00 0.0 798548.0 2349.0 47.492
#
#
#
#
# 2019-04-15T05:15:00 0.0 798559.0 2349.0 37.839
#
#
#
#
# 2019-04-15T05:30:00 0.0 798571.0 2349.0 47.231
#
#
#
#
# 2019-04-15T05:45:00 0.0 798584.0 2349.0 56.445
#
#
#
#
# 2019-04-15T06:00:00 0.0 798599.0 2349.0 67.051
#
#
#
#
# 2019-04-15T06:15:00 0.0 798624.0 2349.0 145.884
#
#
#
#
# 2019-04-15T06:30:00 0.0 798657.0 2349.0 124.011
#
#
#
#
# 2019-04-15T06:45:00 1.0 798690.0 2350.0 68.335
#
#
#
#
# 2019-04-15T07:00:00 1.0 798727.0 2350.0 156.696
#
#
#
#
# 2019-04-15T07:15:00 1.0 798764.0 2350.0 158.218
#
#
#
#
# 2019-04-15T07:30:00 1.0 798804.0 2350.0 145.638
#
#
#
#
# 2019-04-15T07:45:00 1.0 798844.0 2350.0 169.484
#
#
#
#
# 2019-04-15T08:00:00 1.0 798891.0 2350.0 181.635
#
#
#
#
# 2019-04-15T08:15:00 1.0 798938.0 2350.0 194.217
#
#
#
#
# 2019-04-15T08:30:00 1.0 798986.0 2350.0 194.15
#
#
#
#
# 2019-04-15T08:45:00 1.0 799035.0 2350.0 199.957
#
#
#
#
# 2019-04-15T09:00:00 1.0 799084.0 2350.0 211.813
#
#
#
#
# 2019-04-15T09:15:00 1.0 799133.0 2350.0 201.007
#
#
#
#
# 2019-04-15T09:30:00 1.0 799183.0 2350.0 206.689
#
#
#
#
# 2019-04-15T09:45:00 1.0 799233.0 2350.0 196.949
#
#
#
#
# 2019-04-15T10:00:00 1.0 799281.0 2350.0 192.647
#
#
#
#
# 2019-04-15T10:15:00 1.0 799328.0 2350.0 175.862
#
#
#
#
# 2019-04-15T10:30:00 1.0 799376.0 2350.0 196.796
#
#
#
#
# 2019-04-15T10:45:00 1.0 799423.0 2350.0 188.604
#
#
#
#
# 2019-04-15T11:00:00 1.0 799471.0 2350.0 179.28
#
#
#
#
# 2019-04-15T11:15:00 1.0 799516.0 2350.0 200.401
#
#
#
#
# 2019-04-15T11:30:00 1.0 799562.0 2350.0 179.574
#
#
#
#
# 2019-04-15T11:45:00 1.0 799608.0 2350.0 183.164
#
#
#
#
# 2019-04-15T12:00:00 1.0 799653.0 2350.0 189.869
#
#
#
#
# 2019-04-15T12:15:00 1.0 799697.0 2350.0 174.032
#
#
#
#
# 2019-04-15T12:30:00 1.0 799742.0 2350.0 169.018
#
#
#
#
# 2019-04-15T12:45:00 1.0 799785.0 2350.0 180.112
#
#
#
#
# 2019-04-15T13:00:00 1.0 799828.0 2350.0 162.951
#
#
#
#
# 2019-04-15T13:15:00 1.0 799871.0 2350.0 174.147
#
#
#
#
# 2019-04-15T13:30:00 1.0 799914.0 2350.0 176.072
#
#
#
#
# 2019-04-15T13:45:00 1.0 799957.0 2350.0 169.24
#
#
#
#
# 2019-04-15T14:00:00 1.0 799999.0 2350.0 176.008
#
#
#
#
# 2019-04-15T14:15:00 1.0 800043.0 2350.0 180.614
#
#
#
#
# 2019-04-15T14:30:00 1.0 800087.0 2350.0 173.105
#
#
#
#
# 2019-04-15T14:45:00 1.0 800132.0 2350.0 195.352
#
#
#
#
# 2019-04-15T15:00:00 1.0 800175.0 2350.0 161.443
#
#
#
#
# 2019-04-15T15:15:00 1.0 800218.0 2350.0 175.873
#
#
#
#
# 2019-04-15T15:30:00 1.0 800261.0 2350.0 170.161
#
#
#
#
# 2019-04-15T15:45:00 1.0 800304.0 2350.0 166.104
#
#
#
#
# 2019-04-15T16:00:00 1.0 800349.0 2350.0 168.911
#
#
#
#
# 2019-04-15T16:15:00 1.0 800394.0 2350.0 195.745
#
#
#
#
# 2019-04-15T16:30:00 1.0 800441.0 2350.0 180.931
#
#
#
#
# 2019-04-15T16:45:00 1.0 800485.0 2350.0 192.128
#
#
#
#
# 2019-04-15T17:00:00 1.0 800528.0 2350.0 167.369
#
#
#
#
# 2019-04-15T17:15:00 1.0 800569.0 2350.0 170.13
#
#
#
#
# 2019-04-15T17:30:00 1.0 800609.0 2350.0 159.207
#
#
#
#
# 2019-04-15T17:45:00 0.0 800641.0 2353.0 139.288
#
#
#
#
# 2019-04-15T18:00:00 0.0 800677.0 2353.0 142.93
#
#
#
#
# 2019-04-15T18:15:00 0.0 800712.0 2353.0 129.97
#
#
#
#
# 2019-04-15T18:30:00 0.0 800745.0 2353.0 131.704
#
#
#
#
# 2019-04-15T18:45:00 1.0 800772.0 2353.0 59.357
#
#
#
#
# 2019-04-15T19:00:00 1.0 800804.0 2353.0 132.393
#
#
#
#
# 2019-04-15T19:15:00 1.0 800837.0 2353.0 119.694
#
#
#
#
# 2019-04-15T19:30:00 1.0 800869.0 2353.0 129.842
#
#
#
#
# 2019-04-15T19:45:00 1.0 800901.0 2353.0 121.639
#
#
#
#
# 2019-04-15T20:00:00 1.0 800933.0 2353.0 137.071
#
#
#
#
# 2019-04-15T20:15:00 0.0 800960.0 2356.0 128.446
#
#
#
#
# 2019-04-15T20:30:00 0.0 800991.0 2356.0 140.305
#
#
#
#
# 2019-04-15T20:45:00 0.0 801022.0 2356.0 127.353
#
#
#
#
# 2019-04-15T21:00:00 0.0 801052.0 2356.0 123.553
#
#
#
#
# 2019-04-15T21:15:00 0.0 801083.0 2356.0 127.437
#
#
#
#
# 2019-04-15T21:30:00 0.0 801114.0 2356.0 120.415
#
#
#
#
# 2019-04-15T21:45:00 0.0 801145.0 2356.0 121.222
#
#
#
#
# 2019-04-15T22:00:00 0.0 801177.0 2356.0 117.195
#
#
#
#
# 2019-04-15T22:15:00 0.0 801207.0 2356.0 105.132
#
#
#
#
# 2019-04-15T22:30:00 0.0 801233.0 2356.0 80.491
#
#
#
#
# 2019-04-15T22:45:00 0.0 801248.0 2356.0 50.313
#
#
#
#
# 2019-04-15T23:00:00 0.0 801261.0 2356.0 57.143
#
#
#
#
# 2019-04-15T23:15:00 0.0 801273.0 2356.0 44.829
#
#
#
#
# 2019-04-15T23:30:00 0.0 801285.0 2356.0 45.269

# %%
readings = (data['data'][0]['data'])
# # # print(data['data'][0]["recordTime"])
utility_times = []
gen_times = []

for readings in reversed(data['data']):
    record_time = readings["recordTime"]
    digital_in = readings["data"][0]["value"]
    energy_1 = readings["data"][1]["value"]
    energy_2 = readings["data"][2]["value"]
    total_energy = readings["data"][3]["value"]
    
    if digital_in == 0:
        utility_times.append(record_time)
    elif digital_in == 1:
        gen_times.append(record_time)
        
#     # # print(record_time, digital_in,  energy_1,  energy_2,  energy_2,  "\n\n\n\n")

# # print(utility_times)
# # print("\n")
# # print(gen_times)
# Out:
# ['2019-04-15T03:45:00', '2019-04-15T04:00:00', '2019-04-15T04:15:00', '2019-04-15T04:30:00', '2019-04-15T04:45:00', '2019-04-15T05:00:00', '2019-04-15T05:15:00', '2019-04-15T05:30:00', '2019-04-15T05:45:00', '2019-04-15T06:00:00', '2019-04-15T06:15:00', '2019-04-15T06:30:00', '2019-04-15T17:45:00', '2019-04-15T18:00:00', '2019-04-15T18:15:00', '2019-04-15T18:30:00', '2019-04-15T20:15:00', '2019-04-15T20:30:00', '2019-04-15T20:45:00', '2019-04-15T21:00:00', '2019-04-15T21:15:00', '2019-04-15T21:30:00', '2019-04-15T21:45:00', '2019-04-15T22:00:00', '2019-04-15T22:15:00', '2019-04-15T22:30:00', '2019-04-15T22:45:00', '2019-04-15T23:00:00', '2019-04-15T23:15:00', '2019-04-15T23:30:00']
#
#
# ['2019-04-15T00:00:00', '2019-04-15T00:15:00', '2019-04-15T00:30:00', '2019-04-15T00:45:00', '2019-04-15T01:00:00', '2019-04-15T01:15:00', '2019-04-15T01:30:00', '2019-04-15T01:45:00', '2019-04-15T02:00:00', '2019-04-15T02:15:00', '2019-04-15T02:30:00', '2019-04-15T02:45:00', '2019-04-15T03:00:00', '2019-04-15T03:15:00', '2019-04-15T03:30:00', '2019-04-15T06:45:00', '2019-04-15T07:00:00', '2019-04-15T07:15:00', '2019-04-15T07:30:00', '2019-04-15T07:45:00', '2019-04-15T08:00:00', '2019-04-15T08:15:00', '2019-04-15T08:30:00', '2019-04-15T08:45:00', '2019-04-15T09:00:00', '2019-04-15T09:15:00', '2019-04-15T09:30:00', '2019-04-15T09:45:00', '2019-04-15T10:00:00', '2019-04-15T10:15:00', '2019-04-15T10:30:00', '2019-04-15T10:45:00', '2019-04-15T11:00:00', '2019-04-15T11:15:00', '2019-04-15T11:30:00', '2019-04-15T11:45:00', '2019-04-15T12:00:00', '2019-04-15T12:15:00', '2019-04-15T12:30:00', '2019-04-15T12:45:00', '2019-04-15T13:00:00', '2019-04-15T13:15:00', '2019-04-15T13:30:00', '2019-04-15T13:45:00', '2019-04-15T14:00:00', '2019-04-15T14:15:00', '2019-04-15T14:30:00', '2019-04-15T14:45:00', '2019-04-15T15:00:00', '2019-04-15T15:15:00', '2019-04-15T15:30:00', '2019-04-15T15:45:00', '2019-04-15T16:00:00', '2019-04-15T16:15:00', '2019-04-15T16:30:00', '2019-04-15T16:45:00', '2019-04-15T17:00:00', '2019-04-15T17:15:00', '2019-04-15T17:30:00', '2019-04-15T18:45:00', '2019-04-15T19:00:00', '2019-04-15T19:15:00', '2019-04-15T19:30:00', '2019-04-15T19:45:00', '2019-04-15T20:00:00']

# %%
def get_time_dif(a, b):
    import datetime
#     a = datetime.datetime.now()
#     b = datetime.datetime.now()
    c = b - a
    hours = c.seconds/3600
    return hours

# %%
from dateutil import parser

def format_date(date):###THIS FUNCTION CONVERTS DATE FROM DD-MM-YYY TO YYY-MM-DD

    datetime_object = parser.parse(date)

    return datetime_object

format_date('2019-06-28T23:45:00')

x = format_date('2019-06-28T23:45:00')
y = format_date('2019-06-18T23:45:15')

get_time_dif(y, x)
# Out:
# 23.995833333333334

# %%
nums = [1,2,3,4,5,6,7,8,9,0]
num_tuple = []

while len(nums) > 1:
    x,y = nums.pop(0), nums[0]
    
nums = data["data"].copy()

# %%
#  (data['data']).reverse()
nums.reverse()
utility_hrs = []
gen_hrs = []

while len(nums) > 1:
    x,y = nums.pop(0), nums[0]
    
    x_di = x["data"][0]["value"]
    y_di = y["data"][0]["value"]
    x_time, y_time = format_date(x["recordTime"]), format_date(y["recordTime"])
    
    if x_di == 0 and y_di == 1:
        gen_hrs.append(0.25)
        pass
    elif x_di == 1 and y_di == 0:
        utility_hrs.append(0.25)
    elif x_di == y_di == 1:
        time_diff = get_time_dif(x_time, y_time)
#         # # print(x["recordTime"],y["recordTime"], x_di, y_di,"Gen", f"{time_diff}hrs")
        gen_hrs.append(time_diff)

    elif x_di == y_di == 0:
        time_diff = get_time_dif(x_time, y_time)
#         # # print(x["recordTime"],y["recordTime"], x_di, y_di,"NEPA", f"{time_diff}hrs")
        utility_hrs.append(time_diff)
    
# # print(sum(utility_hrs), sum(gen_hrs))

# # print("\n")
# Out:
# 7.5 16.0
